# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold
import pandas as pd
import os
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# %%
def plot_MP_BG(S_lowDWeights):
    plt.cla()
    S_data=pd.DataFrame({'x':S_lowDWeights[:,0],'y':S_lowDWeights[:,1]})
    S_data.columns = ['x', 'y']
    
    X=S_data.loc[:]['x']
    Y=S_data.loc[:]['y']
    plt.scatter(X,Y,marker='o',color='white',s=20,zorder=1, edgecolor="grey")

# %%
allmp_feat   = np.load('./cs_tsne.npy')
allmp_id = pd.read_csv("../aline_feat/cs_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('./gatgnn_tsne.npy')
allmp_id = pd.read_csv("../aline_feat/gatgnn_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('./pwdm_tsne.npy')
allmp_id = pd.read_csv("../aline_feat/pwdm_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('./spn_tsne.npy')
allmp_id = pd.read_csv("../aline_feat/spn_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('./xrd_tsne.npy')
allmp_id = pd.read_csv("../aline_feat/xrd_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('./cod0_tsne.npy')
allmp_id = pd.read_csv("../aline_feat/cod0_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('./codv_tsne.npy')
allmp_id = pd.read_csv("../aline_feat/cod0_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('./topo_tsne.npy')
allmp_id = pd.read_csv("../aline_feat/topo_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('../Ccod0_tsne.npy')
allmp_id = pd.read_csv("../../aline_feat/Ccod0_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('../Fcod0_tsne.npy')
allmp_id = pd.read_csv("../../aline_feat/Fcod0_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('../CcodV_tsne.npy')
allmp_id = pd.read_csv("../../aline_feat/CcodV_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('../FcodV_tsne.npy')
allmp_id = pd.read_csv("../../aline_feat/FcodV_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('../pwdmr_tsne.npy')
allmp_id = pd.read_csv("../../aline_feat/pwdmrad_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('../comp_tsne.npy')
allmp_id = pd.read_csv("../../aline_feat/pwdmrad_aline_feat.csv").mp_id.to_frame()

# %%
allmp_feat   = np.load('../compVAE_tsne.npy')
allmp_id = pd.read_csv("../../aline_feat/compVAE_aline_feat.csv").mp_id.to_frame()

# %%
len(allmp_feat)
allmp_id
# Out:
#              mp_id
# 0       mp-1184264
# 1       mp-1212998
# 2        mp-505364
# 3       mp-1312784
# 4       mp-1221704
# ...            ...
# 136066  mp-1029274
# 136067   mp-764882
# 136068     mp-3271
# 136069   mp-559813
# 136070   mp-558696
#
# [136071 rows x 1 columns]

# %%
allmp_id.columns =['mp_id']
allmp_id['tsne'] = allmp_feat.tolist()
x = allmp_feat[:,0]
y = allmp_feat[:,1]
allmp_id['x'] = x
allmp_id['y'] = y

# %%
allmp_id
# Out:
#              mp_id                                        tsne         x  \
# 0       mp-1184264    [0.9981968998908997, 0.5249232649803162]  0.998197
# 1       mp-1212998    [0.8182021379470825, 0.5464243292808533]  0.818202
# 2        mp-505364  [0.48219040036201477, 0.22304454445838928]  0.482190
# 3       mp-1312784    [0.2675015330314636, 0.3291451334953308]  0.267502
# 4       mp-1221704   [0.49290862679481506, 0.5353098511695862]  0.492909
# ...            ...                                         ...       ...
# 136066  mp-1029274     [0.5735797882080078, 0.760564923286438]  0.573580
# 136067   mp-764882   [0.8633913397789001, 0.39483407139778137]  0.863391
# 136068     mp-3271   [0.5708091259002686, 0.32695290446281433]  0.570809
# 136069   mp-559813    [0.2634724974632263, 0.9334959387779236]  0.263472
# 136070   mp-558696    [0.4040674865245819, 0.8579456210136414]  0.404067
#
#                y
# 0       0.524923
# 1       0.546424
# 2       0.223045
# 3       0.329145
# ...

# %%
allmp_id = pd.read_csv("../../allmp_pwdm100_xy.csv")

# %%
allmp_id = pd.read_csv("../../allmp_pwdm100rad_xy.csv")

# %%
allmp_id
# Out:
#         Unnamed: 0       mp_id                                        tsne  \
# 0                0  mp-1184264  [0.17208996415138245, 0.26798802614212036]
# 1                1  mp-1212998   [0.6187732219696045, 0.25983965396881104]
# 2                2   mp-505364    [0.2476155310869217, 0.5543716549873352]
# 3                3  mp-1312784    [0.9139175415039062, 0.8047369122505188]
# 4                4  mp-1221704   [0.3304295241832733, 0.29297247529029846]
# ...            ...         ...                                         ...
# 136066      136066  mp-1029274   [0.7025770545005798, 0.06319572776556015]
# 136067      136067   mp-764882     [0.8789435625076294, 0.673820972442627]
# 136068      136068     mp-3271   [0.7875974774360657, 0.15780429542064667]
# 136069      136069   mp-559813    [0.5505833029747009, 0.7195977568626404]
# 136070      136070   mp-558696    [0.8638137578964233, 0.5837963819503784]
#
#                x         y
# 0       0.172090  0.267988
# ...

# %%
import matplotlib as mpl


fig = plt.figure(figsize=(20,20),dpi=100)
ax1 = fig.add_subplot(111)
#plot_MP_BG(allmp_id)
#plt.show()
#plot_BG(select_data)

x=allmp_id.loc[:]['x']
y=allmp_id.loc[:]['y']
plt.scatter(x,y,marker='o',color='white',s=20,zorder=1, edgecolor="grey")
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)
plt.scatter(x, y, c=z, s=1,zorder=3,cmap=mpl.colormaps['YlOrRd'])

plt.subplots_adjust(left=None, bottom=0.15, right=None, top=None,
                wspace=0.1, hspace=0.15)
plt.legend(labels = ['alldata'], loc='lower left')
plt.xticks()
plt.show()
